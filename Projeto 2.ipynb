# %% [markdown]
# # Projeto 2 - análise de dados
# ### Turismo mundial

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Gabriela\Documents\INSPER\2Semestre.2\CDados\Projeto-2

# %%
dados = pd.read_excel('Dados_turismo.xlsx')
dados.head()
# Out:
#           Country int inbound 2012 int inbound 2018 int outbound 2012  \
# 0     Afghanistan               ..               ..                ..
# 1         Albania            3.156             5.34             3.959
# 2         Algeria            2.634            2.657             1.911
# 3  American Samoa               23               20                ..
# 4         Andorra            2.238            3.042                ..
#
#   int outbound 2018 inbound exp 2012  (millions) inbound exp 2018  (millions)  \
# 0                ..                          167                           50
# 1             5.415                        1.623                        2.306
# 2              5.61                          295                           ..
# 3                ..                           ..                           ..
# 4                ..                           ..                           ..
#
#   inbound exp 2012  (percentage) inbound exp 2018  (percentage)  \
# ...
